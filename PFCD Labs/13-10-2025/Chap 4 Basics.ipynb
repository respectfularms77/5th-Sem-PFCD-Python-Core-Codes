# %%
import random as rd
for i in range(10):
    print(rd.randrange(1,7),end=" ")
# Out:
# 4 1 3 1 1 5 1 6 2 4

# %%
import random as rd
rd.seed(32)
for i in range(10):
    print(rd.randrange(1,7),end=" ")
# Out:
# 1 2 2 3 6 2 4 1 6 1

# %%
import random as rd
rd.seed(32)
for i in range(10):
    print(rd.randrange(1,7),end=" ")
# Out:
# 1 2 2 3 6 2 4 1 6 1

# %%
import random as rd
rd.seed(40)
for i in range(10):
    print(rd.randrange(1,7),end=" ")
# Out:
# 4 5 5 1 2 3 6 6 6 2
